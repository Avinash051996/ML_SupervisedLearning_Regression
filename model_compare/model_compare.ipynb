# %%
# # Linear regression model Evaluations Results
# MAE  : 1.16
# MSE  : 2.40
# RMSE : 1.55
# R²   : 0.885

# %%
## Ridge Model Evaluation Results
# Best Hyperparameters: {'alpha': 10.0, 'solver': 'sparse_cg'}
# Mean Absolute Error (MAE) after tuning: 1.1603613988142674
# Mean Squared Error (MSE) after tuning: 2.39503052219139
# Root Mean Squared Error (RMSE) after tuning: 1.5475886152952243
# R-squared (R2 ) after tuning: 0.885234934477351

# %%
# # Lasso model Evaluations results
# Mean Absolute Error (MAE): 1.5084303356570734
# Mean Squared Error (MSE): 4.181901596762411
# Root Mean Squared Error (RMSE): 2.0449698278366872
# R-squared (R2 ): 0.7996116515782107

# %%
# Random Forest Regressor Performance:
# Mean Absolute Error (MAE): 0.64
# Mean Squared Error (MSE): 1.02
# R-squared (R2 ): 0.95
# Root Mean Squared Error (RMSE): 1.01

# %%
# Gradient Boosting Regressor Performance:
# Mean Absolute Error (MAE): 0.61
# Mean Squared Error (MSE): 0.93
# R-squared (R2 ): 0.96
# Root Mean Squared Error (RMSE): 0.97

# %%
# XGBoost Regressor Performance:
# Mean Absolute Error (MAE): 0.59
# Mean Squared Error (MSE): 0.89
# R-squared (R2 ): 0.96
# Root Mean Squared Error (RMSE): 0.95
